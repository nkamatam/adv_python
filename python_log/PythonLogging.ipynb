# %%
#without logging

def add(num1, num2):
    return num1 + num2

def substract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    return num1 / num2

a=10
b=2

result_add = add(a, b)
print('Add : {} + {}  = {}'.format(a, b, result_add))


result_sub = substract(a, b)
print('Add : {} - {}  = {}'.format(a, b, result_sub))


result_mul = multiply(a, b)
print('Add : {} * {}  = {}'.format(a, b, result_mul))


result_div = divide(a, b)
print('Add : {} / {}  = {}'.format(a, b, result_div))
# Out:
# Add : 10 + 2  = 12
# Add : 10 - 2  = 8
# Add : 10 * 2  = 20
# Add : 10 / 2  = 5.0

# %%
# with basic logging

import logging

logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %% [markdown]
# Debug - Details information, typically of interest only when diagnosing problems.
#
# Info - Confirmation that things are working as expected
#
# Warning - An indication that something unexpected happened, or indicative of some problem in the near future (disk
# space low, etc). The software still working as expected
#
# Error - Due to a more serious problem, the software has not been able to perform some functions
#
# Critical - A serious error, indicating that the prgram itself may be unable to continue running.
#
# Root - By Default you work with the root logger, specific loggers can be configured seperately

# %%
#with basic logging

import logging

def add(num1, num2):
    return num1 + num2

def substract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    return num1 / num2

a=10
b=2

result_add = add(a, b)
logging.warning('Add : {} + {}  = {}'.format(a, b, result_add))


result_sub = substract(a, b)
logging.warning('Add : {} - {}  = {}'.format(a, b, result_sub))


result_mul = multiply(a, b)
logging.warning('Add : {} * {}  = {}'.format(a, b, result_mul))


result_div = divide(a, b)
logging.warning('Add : {} / {}  = {}'.format(a, b, result_div))
# Out:
# WARNING:root:Add : 10 + 2  = 12
# WARNING:root:Add : 10 - 2  = 8
# WARNING:root:Add : 10 * 2  = 20
# WARNING:root:Add : 10 / 2  = 5.0

# %%
#change the logging level

#with basic logging

import logging

logging.basicConfig(level=logging.DEBUG)

def add(num1, num2):
    return num1 + num2

def substract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    return num1 / num2

a=10
b=2

result_add = add(a, b)
logging.info('Add : {} + {}  = {}'.format(a, b, result_add))


result_sub = substract(a, b)
logging.info('Add : {} - {}  = {}'.format(a, b, result_sub))


result_mul = multiply(a, b)
logging.info('Add : {} * {}  = {}'.format(a, b, result_mul))


result_div = divide(a, b)
logging.info('Add : {} / {}  = {}'.format(a, b, result_div))
# Out:
# INFO:root:Add : 10 + 2  = 12
# INFO:root:Add : 10 - 2  = 8
# INFO:root:Add : 10 * 2  = 20
# INFO:root:Add : 10 / 2  = 5.0

# %%
#log data to file


#change the logging level

#with basic logging

import logging

logging.basicConfig(filename = 'app.log', level=logging.DEBUG)

def add(num1, num2):
    return num1 + num2

def substract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    return num1 / num2

a=10
b=2

result_add = add(a, b)
logging.info('Add : {} + {}  = {}'.format(a, b, result_add))


result_sub = substract(a, b)
logging.info('Add : {} - {}  = {}'.format(a, b, result_sub))


result_mul = multiply(a, b)
logging.info('Add : {} * {}  = {}'.format(a, b, result_mul))


result_div = divide(a, b)
logging.info('Add : {} / {}  = {}'.format(a, b, result_div))

# %%
#log data to file and format the message
# https://docs.python.org/2/library/logging.html#logrecord-attributes


import logging

logging.basicConfig(filename = 'app.log', level=logging.DEBUG, format='%(asctime)s:%(levelname)s:%(message)s')

def add(num1, num2):
    return num1 + num2

def substract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    return num1 / num2

a=10
b=2

result_add = add(a, b)
logging.info('Add : {} + {}  = {}'.format(a, b, result_add))


result_sub = substract(a, b)
logging.info('Add : {} - {}  = {}'.format(a, b, result_sub))


result_mul = multiply(a, b)
logging.info('Add : {} * {}  = {}'.format(a, b, result_mul))


result_div = divide(a, b)
logging.info('Add : {} / {}  = {}'.format(a, b, result_div))

# %%
#log data to file and format the message
# https://docs.python.org/2/library/logging.html#logrecord-attributes


import logging
import power

logging.basicConfig(filename = 'app.log', level=logging.DEBUG, format='%(asctime)s:%(levelname)s:%(message)s')

def add(num1, num2):
    return num1 + num2

def substract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    return num1 / num2

a=10
b=2

result_add = add(a, b)
logging.debug('Add : {} + {}  = {}'.format(a, b, result_add))


result_sub = substract(a, b)
logging.debug('Add : {} - {}  = {}'.format(a, b, result_sub))


result_mul = multiply(a, b)
logging.debug('Add : {} * {}  = {}'.format(a, b, result_mul))


result_div = divide(a, b)
logging.debug('Add : {} / {}  = {}'.format(a, b, result_div))
